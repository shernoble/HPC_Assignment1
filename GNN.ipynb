# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GCNConv
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures

print("KAVYA SHRIDHAR LOLLA S20210010117, JAI SRI AISHWARYA S20210010070")
# Load the Cora dataset
dataset = Planetoid(root='data/Cora', name='Cora', transform=NormalizeFeatures())
data = dataset[0]

# Define a larger Graph Neural Network model
class LargerGNN(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers, dropout=0.5):
        super(LargerGNN, self).__init__()
        self.conv_layers = nn.ModuleList()

        # First Graph Convolutional Layer
        self.conv_layers.append(GCNConv(in_channels, hidden_channels))

        # Intermediate Graph Convolutional Layers
        for _ in range(num_layers - 2):
            self.conv_layers.append(GCNConv(hidden_channels, hidden_channels))

        # Last Graph Convolutional Layer
        self.conv_layers.append(GCNConv(hidden_channels, out_channels))

        # Dropout layer for regularization
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, edge_index):
        for conv in self.conv_layers[:-1]:
            x = torch.relu(conv(x, edge_index))
            x = self.dropout(x)  # Apply dropout for regularization

        x = self.conv_layers[-1](x, edge_index)
        return x

# Instantiate the larger model
larger_model = LargerGNN(in_channels=dataset.num_node_features,
                         hidden_channels=256,  # Increased hidden layer dimensions
                         out_channels=dataset.num_classes,
                         num_layers=6)  # Increased number of layers

# Use the Adam optimizer with a larger learning rate
optimizer = optim.Adam(larger_model.parameters(), lr=0.01)

# Loss function
criterion = nn.CrossEntropyLoss()

# Training function
def train_larger_model(model, data, optimizer, criterion, epochs=200):
    model.train()
    for epoch in range(epochs):
        optimizer.zero_grad()
        out = model(data.x, data.edge_index)
        loss = criterion(out[data.train_mask], data.y[data.train_mask])
        loss.backward()
        optimizer.step()
        if epoch % 20 == 0:
            print(f'Epoch {epoch}, Loss: {loss.item()}')

# print("KAVYA SHRIDHAR LOLLA S20210010117, JAI SRI AISHWARYA S20210010070")
# %prun -s cumulative -T profile_output.txt train_larger_model(larger_model, data, optimizer, criterion)
# Out:
# KAVYA SHRIDHAR LOLLA S20210010117, JAI SRI AISHWARYA S20210010070
# Epoch 0, Loss: 1.9456897974014282
# Epoch 20, Loss: 0.25219616293907166
# Epoch 40, Loss: 0.03076844848692417
# Epoch 60, Loss: 0.2281217724084854
# Epoch 80, Loss: 0.048897407948970795
# Epoch 100, Loss: 0.001608305494301021
# Epoch 120, Loss: 0.017081458121538162
# Epoch 140, Loss: 0.02986166812479496
# Epoch 160, Loss: 0.00011302893835818395
# Epoch 180, Loss: 0.22326524555683136
#
# *** Profile printout saved to text file 'profile_output.txt'.
#          286678 function calls (276637 primitive calls) in 28.973 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   28.973   28.973 {built-in method builtins.exec}
#         1    0.004    0.004   28.972   28.972 <string>:1(<module>)
#         1    0.030    0.030   28.969   28.969 2322309956.py:54(train_larger_model)
#  5000/400    0.023    0.000   14.026    0.035 module.py:1514(_wrapped_call_impl)
#  5000/400    0.047    0.000   14.025    0.035 module.py:1520(_call_impl)
#       200    0.034    0.000   13.998    0.070 2322309956.py:33(forward)
#       200    0.002    0.000   13.833    0.069 _tensor.py:433(backward)
#       200    0.003    0.000   13.830    0.069 __init__.py:149(backward)
#       200   13.822    0.069   13.822    0.069 {method 'run_backward' of 'torch._C._EngineBase' objects}
#      1200    0.573    0.000   11.899    0.010 gcn_conv.py:208(forward)
#      1200    0.065    0.000    7.079    0.006 message_passing.py:378(propagate)
#      1200    0.008    0.000    3.450    0.003 linear.py:125(forward)
#      1200    3.440    0.003    3.440    0.003 {built-in method torch._C._nn.linear}
#      1200    2.827    0.002    2.844    0.002 gcn_conv.py:252(message)
#      1200    0.018    0.000    2.338    0.002 message_passing.py:591(aggregate)
#      2400    0.033    0.000    2.330    0.001 scatter.py:15(scatter)
#      1200    0.006    0.000    2.316    0.002 experimental.py:112(wrapper)
#      1200    0.010    0.000    2.284    0.002 base.py:95(__call__)
#      1200    0.003    0.000    2.251    0.002 basic.py:19(forward)
#      1200    0.004    0.000    2.248    0.002 base.py:167(reduce)
#      2400    1.840    0.001    1.840    0.001 {method 'scatter_add_' of 'torch._C._TensorBase' objects}
#      1200    0.066    0.000    1.760    0.001 message_passing.py:310(_collect)
#      1200    0.027    0.000    1.680    0.001 message_passing.py:243(_lift)
#      1200    1.652    0.001    1.652    0.001 {method 'index_select' of 'torch._C._TensorBase' objects}
#      1000    0.005    0.000    1.533    0.002 dropout.py:57(forward)
#      1000    0.012    0.000    1.528    0.002 functional.py:1249(dropout)
#      1000    1.513    0.002    1.513    0.002 {built-in method torch.dropout}
#       200    0.008    0.000    0.981    0.005 optimizer.py:356(wrapper)
#       200    0.004    0.000    0.951    0.005 optimizer.py:58(_use_grad)
#       200    0.003    0.000    0.944    0.005 adam.py:130(step)
#       200    0.002    0.000    0.924    0.005 adam.py:254(adam)
#       200    0.161    0.001    0.914    0.005 adam.py:330(_single_tensor_adam)
#      1200    0.215    0.000    0.763    0.001 gcn_conv.py:43(gcn_norm)
#      1000    0.461    0.000    0.461    0.000 {built-in method torch.relu}
#      2400    0.394    0.000    0.394    0.000 {method 'new_zeros' of 'torch._C._TensorBase' objects}
#      1200    0.238    0.000    0.384    0.000 loop.py:300(add_remaining_self_loops)
#      2400    0.339    0.000    0.339    0.000 {method 'lerp_' of 'torch._C._TensorBase' objects}
#      2400    0.125    0.000    0.125    0.000 {method 'addcdiv_' of 'torch._C._TensorBase' objects}
#       200    0.002    0.000    0.089    0.000 _compile.py:20(inner)
#      2400    0.088    0.000    0.088    0.000 {method 'addcmul_' of 'torch._C._TensorBase' objects}
#      2400    0.081    0.000    0.081    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#      1200    0.068    0.000    0.068    0.000 {built-in method torch.cat}
#      2400    0.067    0.000    0.067    0.000 {method 'sqrt' of 'torch._C._TensorBase' objects}
#       200    0.001    0.000    0.062    0.000 decorators.py:33(disable)
#       200    0.004    0.000    0.058    0.000 eval_frame.py:267(__call__)
#      2400    0.012    0.000    0.057    0.000 scatter.py:161(broadcast)
#       200    0.003    0.000    0.050    0.000 inspect.py:936(getsourcefile)
#      3600    0.042    0.000    0.042    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#       200    0.001    0.000    0.042    0.000 <frozen genericpath>:16(exists)
#       200    0.041    0.000    0.041    0.000 {built-in method nt.stat}
#      1200    0.014    0.000    0.040    0.000 message_passing.py:196(_check_input)
#      1200    0.037    0.000    0.037    0.000 {method 'repeat' of 'torch._C._TensorBase' objects}
#      2400    0.031    0.000    0.031    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#      1200    0.031    0.000    0.031    0.000 {built-in method torch.arange}
#      1200    0.030    0.000    0.030    0.000 {built-in method torch.ones}
#      6000    0.026    0.000    0.028    0.000 sparse.py:114(is_torch_sparse_tensor)
#      1200    0.011    0.000    0.026    0.000 experimental.py:26(is_experimental_mode_enabled)
#       200    0.002    0.000    0.026    0.000 eval_frame.py:307(_fn)
#      3600    0.023    0.000    0.026    0.000 inspector.py:52(distribute)
#      1200    0.026    0.000    0.026    0.000 {method 'pow_' of 'torch._C._TensorBase' objects}
#       200    0.002    0.000    0.024    0.000 loss.py:1178(forward)
#       200    0.001    0.000    0.022    0.000 functional.py:2963(cross_entropy)
#       400    0.003    0.000    0.021    0.000 container.py:288(__getitem__)
#      5000    0.021    0.000    0.021    0.000 {built-in method torch._C._get_tracing_state}
#      9800    0.021    0.000    0.021    0.000 module.py:1682(__getattr__)
#       200    0.020    0.000    0.020    0.000 {built-in method torch._C._nn.cross_entropy_loss}
#       200    0.007    0.000    0.020    0.000 optimizer.py:776(zero_grad)
#      2400    0.007    0.000    0.019    0.000 _trace.py:1110(is_tracing)
#       400    0.002    0.000    0.019    0.000 profiler.py:630(__enter__)
#      2400    0.018    0.000    0.018    0.000 {method 'expand_as' of 'torch._C._TensorBase' objects}
#       400    0.001    0.000    0.016    0.000 _ops.py:687(__call__)
#       200    0.011    0.000    0.016    0.000 adam.py:80(_init_group)
#       400    0.016    0.000    0.016    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#       200    0.001    0.000    0.015    0.000 container.py:274(__init__)
#      9600    0.015    0.000    0.015    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#      2400    0.004    0.000    0.015    0.000 sparse.py:132(is_sparse)
#      1200    0.012    0.000    0.012    0.000 {method 'masked_fill_' of 'torch._C._TensorBase' objects}
#      2400    0.012    0.000    0.012    0.000 {built-in method torch._C._is_tracing}
#      2400    0.005    0.000    0.011    0.000 optimizer.py:84(_get_value)
#       400    0.004    0.000    0.011    0.000 profiler.py:636(__exit__)
#       200    0.000    0.000    0.011    0.000 container.py:317(__iadd__)
#       200    0.002    0.000    0.010    0.000 container.py:389(extend)
#      1200    0.010    0.000    0.010    0.000 {method 'unsqueeze' of 'torch._C._TensorBase' objects}
# 34304/34283    0.008    0.000    0.009    0.000 {built-in method builtins.isinstance}
#      1000    0.002    0.000    0.007    0.000 module.py:599(add_module)
#      2400    0.004    0.000    0.007    0.000 optimizer.py:97(_dispatch_sqrt)
#       400    0.001    0.000    0.007    0.000 _ops.py:447(__call__)
#       400    0.006    0.000    0.006    0.000 {built-in method torch._ops.profiler.}
#       200    0.002    0.000    0.006    0.000 optimizer.py:109(_default_to_fused_or_foreach)
#      2410    0.005    0.000    0.005    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#      1600    0.001    0.000    0.005    0.000 {built-in method builtins.all}
#      1800    0.003    0.000    0.005    0.000 {built-in method builtins.hasattr}
#       200    0.002    0.000    0.004    0.000 __init__.py:56(_make_grads)
#     12000    0.004    0.000    0.004    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#       200    0.001    0.000    0.004    0.000 package_importer.py:692(_patched_getfile)
#       400    0.002    0.000    0.004    0.000 profiler.py:619(__init__)
#       200    0.003    0.000    0.004    0.000 module.py:451(__init__)
#      3400    0.003    0.000    0.003    0.000 {built-in method builtins.getattr}
#      1200    0.002    0.000    0.003    0.000 message_passing.py:234(_set_size)
#      9400    0.003    0.000    0.003    0.000 {method 'values' of 'collections.OrderedDict' objects}
#        10    0.000    0.000    0.003    0.000 {built-in method builtins.print}
#        20    0.000    0.000    0.003    0.000 iostream.py:624(write)
#      1000    0.002    0.000    0.003    0.000 _VF.py:26(__getattr__)
#       200    0.001    0.000    0.003    0.000 inspect.py:896(getfile)
#      8863    0.003    0.000    0.003    0.000 {method 'get' of 'dict' objects}
#       400    0.003    0.000    0.003    0.000 optimizer.py:122(<genexpr>)
#       200    0.002    0.000    0.003    0.000 container.py:279(_get_abs_string_index)
#        20    0.000    0.000    0.003    0.000 iostream.py:546(_schedule_flush)
#        10    0.000    0.000    0.003    0.000 iostream.py:258(schedule)
#       400    0.001    0.000    0.002    0.000 grad_mode.py:182(__init__)
#       200    0.001    0.000    0.002    0.000 functools.py:35(update_wrapper)
#      1200    0.002    0.000    0.002    0.000 experimental.py:18(get_options)
#        10    0.002    0.000    0.002    0.000 socket.py:621(send)
#       400    0.001    0.000    0.002    0.000 data.py:475(__getattr__)
#      2400    0.002    0.000    0.002    0.000 {built-in method torch.is_complex}
#       200    0.002    0.000    0.002    0.000 {built-in method torch.ones_like}
#       200    0.001    0.000    0.002    0.000 eval_frame.py:442(__init__)
#        24    0.002    0.000    0.002    0.000 {built-in method torch.zeros_like}
#       400    0.001    0.000    0.002    0.000 {built-in method builtins.any}
#      9200    0.002    0.000    0.002    0.000 _jit_internal.py:1109(is_scripting)
# 4220/3420    0.001    0.000    0.002    0.000 {built-in method builtins.len}
#      2400    0.002    0.000    0.002    0.000 {method 'conj' of 'torch._C._TensorBase' objects}
#      1200    0.002    0.000    0.002    0.000 experimental.py:33(<listcomp>)
#     12200    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#       200    0.000    0.000    0.002    0.000 contextlib.py:299(helper)
#      2412    0.001    0.000    0.001    0.000 _tensor.py:1002(__hash__)
#      2400    0.001    0.000    0.001    0.000 message_passing.py:548(explain)
#       200    0.001    0.000    0.001    0.000 data.py:845(x)
#      3621    0.001    0.000    0.001    0.000 {method 'items' of 'collections.OrderedDict' objects}
#      2600    0.001    0.000    0.001    0.000 adam.py:296(<genexpr>)
#       200    0.001    0.000    0.001    0.000 contextlib.py:141(__exit__)
#      2400    0.001    0.000    0.001    0.000 {built-in method math.sqrt}
#       400    0.001    0.000    0.001    0.000 typing.py:359(inner)
#       200    0.001    0.000    0.001    0.000 eval_frame.py:221(__init__)
#       200    0.001    0.000    0.001    0.000 contextlib.py:104(__init__)
#       200    0.001    0.000    0.001    0.000 optimizer.py:309(_cuda_graph_capture_health_check)
#       200    0.001    0.000    0.001    0.000 data.py:861(y)
#       600    0.001    0.000    0.001    0.000 <frozen _collections_abc>:778(__contains__)
#       600    0.000    0.000    0.001    0.000 inspect.py:943(<genexpr>)
#      5200    0.001    0.000    0.001    0.000 _utils.py:841(is_compiling)
#       400    0.001    0.000    0.001    0.000 {built-in method torch._C._set_grad_enabled}
#      1600    0.001    0.000    0.001    0.000 storage.py:110(__getitem__)
#      1200    0.001    0.000    0.001    0.000 {built-in method torch._C._has_torch_function_unary}
#       200    0.001    0.000    0.001    0.000 {built-in method torch._C._log_api_usage_once}
#       400    0.000    0.000    0.001    0.000 storage.py:80(__getattr__)
#       400    0.000    0.000    0.001    0.000 eval_frame.py:192(innermost_fn)
#       200    0.000    0.000    0.001    0.000 <frozen abc>:117(__instancecheck__)
#       400    0.001    0.000    0.001    0.000 {built-in method builtins.next}
#       800    0.001    0.000    0.001    0.000 {method 'endswith' of 'str' objects}
#       800    0.000    0.000    0.001    0.000 container.py:309(__len__)
#       200    0.000    0.000    0.001    0.000 _foreach_utils.py:14(_get_fused_kernels_supported_devices)
#      2412    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#       200    0.000    0.000    0.001    0.000 data.py:849(edge_index)
#       200    0.001    0.000    0.001    0.000 functools.py:65(wraps)
#       200    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#       600    0.000    0.000    0.000    0.000 data.py:497(__getitem__)
#       200    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#      2400    0.000    0.000    0.000    0.000 num_nodes.py:29(maybe_num_nodes)
#       600    0.000    0.000    0.000    0.000 inspect.py:946(<genexpr>)
#       600    0.000    0.000    0.000    0.000 {built-in method torch.is_grad_enabled}
#       200    0.000    0.000    0.000    0.000 skipfiles.py:205(check)
#       400    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#       200    0.000    0.000    0.000    0.000 inspect.py:283(ismodule)
#       200    0.000    0.000    0.000    0.000 {built-in method torch._C._are_functorch_transforms_active}
#       200    0.000    0.000    0.000    0.000 container.py:313(__iter__)
#       400    0.000    0.000    0.000    0.000 {built-in method torch._C._dynamo.eval_frame.set_eval_frame}
#      21/1    0.000    0.000    0.000    0.000 module.py:2379(train)
#      1000    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#       400    0.000    0.000    0.000    0.000 {built-in method torch._C._get_privateuse1_backend_name}
#       200    0.000    0.000    0.000    0.000 inspect.py:378(isfunction)
#       200    0.000    0.000    0.000    0.000 inspect.py:456(istraceback)
#       200    0.000    0.000    0.000    0.000 inspect.py:300(ismethod)
#       200    0.000    0.000    0.000    0.000 _foreach_utils.py:8(_get_foreach_kernels_supported_devices)
#       200    0.000    0.000    0.000    0.000 _reduction.py:7(get_enum)
#       200    0.000    0.000    0.000    0.000 __init__.py:29(is_built)
#       200    0.000    0.000    0.000    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#      1200    0.000    0.000    0.000    0.000 message_passing.py:621(update)
#       200    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       200    0.000    0.000    0.000    0.000 inspect.py:466(isframe)
#       200    0.000    0.000    0.000    0.000 __init__.py:139(_tensor_or_tensors_to_tuple)
#       200    0.000    0.000    0.000    0.000 inspect.py:480(iscode)
#       400    0.000    0.000    0.000    0.000 decorators.py:141(graph_break)
#        21    0.000    0.000    0.000    0.000 module.py:1697(__setattr__)
#       600    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       200    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#        12    0.000    0.000    0.000    0.000 {built-in method torch.tensor}
#       400    0.000    0.000    0.000    0.000 {method '__exit__' of 'torch._C.DisableTorchFunctionSubclass' objects}
#       200    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_variadic}
#       200    0.000    0.000    0.000    0.000 contextlib.py:763(__init__)
#       400    0.000    0.000    0.000    0.000 eval_frame.py:205(enable_dynamic)
#        10    0.000    0.000    0.000    0.000 threading.py:1192(is_alive)
#       400    0.000    0.000    0.000    0.000 eval_frame.py:188(nothing)
#        41    0.000    0.000    0.000    0.000 module.py:2278(children)
#        20    0.000    0.000    0.000    0.000 iostream.py:519(_is_master_process)
#       400    0.000    0.000    0.000    0.000 __init__.py:124(annotate)
#       200    0.000    0.000    0.000    0.000 optimizer.py:340(_optimizer_step_code)
#        41    0.000    0.000    0.000    0.000 module.py:2287(named_children)
#       200    0.000    0.000    0.000    0.000 contextlib.py:766(__enter__)
#       200    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#       200    0.000    0.000    0.000    0.000 typing.py:2268(cast)
#        10    0.000    0.000    0.000    0.000 threading.py:1125(_wait_for_tstate_lock)
#        21    0.000    0.000    0.000    0.000 parameter.py:8(__instancecheck__)
#       200    0.000    0.000    0.000    0.000 contextlib.py:769(__exit__)
#        10    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#        10    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        20    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        20    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        20    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        10    0.000    0.000    0.000    0.000 threading.py:575(is_set)
#        10    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        21    0.000    0.000    0.000    0.000 {function _ParameterMeta.__instancecheck__ at 0x0000014C14765620}
#        20    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
